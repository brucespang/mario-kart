# %%
import numpy as np
import pandas as pd
import plorts
import matplotlib.pyplot as plt
plt.style.use(['plorts', 'plorts-web'])

# %%
df = pd.read_csv('MK8DX 2.3.0 Kart Combinations.xlsx - Combinations.csv')
df = df.drop(columns=['#', 'Unnamed: 1', 'Unnamed: 3', 'Unnamed: 5', 'Unnamed: 7'])

# %%
df[(df['Character'].str.contains('Toadette'))&(df['Body'].str.contains('Prancer'))&(df['Gliders'].str.contains('Super Glider'))&(df['Tires'].str.contains('Wood'))][['Character', 'Body', 'Gliders', 'Tires', 'Speed Ground', 'Handling Ground', 'Traction', 'MiniTurbo']]
# Out:
#                       Character                           Body  \
# 4947  Toadette, Wendy, Isabelle  Prancer, Sport Bike, Jet Bike
#
#                                      Gliders                     Tires  \
# 4947  Super Glider, Waddle Wing, Hylian Kite  Slim, Wood, Crimson Slim
#
#       Speed Ground  Handling Ground  Traction  MiniTurbo
# 4947           3.5              4.5      2.25       3.75

# %%
df[(df['Character'].str.contains('Wario'))&(df['Body'].str.contains('Prancer'))&(df['Gliders'].str.contains('Super Glider'))&(df['Tires'].str.contains('Wood'))][['Character', 'Body', 'Gliders', 'Tires', 'Speed Ground', 'Handling Ground', 'Traction', 'MiniTurbo']]
# Out:
#              Character                           Body  \
# 685  Wario, Dry Bowser  Prancer, Sport Bike, Jet Bike
#
#                                     Gliders                     Tires  \
# 685  Super Glider, Waddle Wing, Hylian Kite  Slim, Wood, Crimson Slim
#
#      Speed Ground  Handling Ground  Traction  MiniTurbo
# 685          5.25              3.0       2.0       2.75

# %%
df[(df['Speed Ground'] >= 5)&(df['MiniTurbo'] > 2.75)][['Character', 'Body', 'Gliders', 'Tires', 'Speed Ground', 'Handling Ground', 'Traction', 'MiniTurbo']]
# Out:
#                        Character  \
# 345            Wario, Dry Bowser
# 346            Wario, Dry Bowser
# 502            Wario, Dry Bowser
# 503            Wario, Dry Bowser
# 515            Wario, Dry Bowser
# 516            Wario, Dry Bowser
# 554            Wario, Dry Bowser
# 555            Wario, Dry Bowser
# 560  Bowser, Morton, Mii (Heavy)
# 561  Bowser, Morton, Mii (Heavy)
# 596            Wario, Dry Bowser
# 634    Donkey Kong, Waluigi, Roy
# 635    Donkey Kong, Waluigi, Roy
# 640            Wario, Dry Bowser
# 647            Wario, Dry Bowser
# 678    Donkey Kong, Waluigi, Roy
# 679    Donkey Kong, Waluigi, Roy
# 687            Wario, Dry Bowser
# 688            Wario, Dry Bowser
# 689            Wario, Dry Bowser
# 692  Bowser, Morton, Mii (Heavy)
# 693  Bowser, Morton, Mii (Heavy)
# 705  Bowser, Morton, Mii (Heavy)
# 706  Bowser, Morton, Mii (Heavy)
# 725  Bowser, Morton, Mii (Heavy)
# 726  Bowser, Morton, Mii (Heavy)
# 751            Wario, Dry Bowser
# ...
